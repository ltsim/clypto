# %%
from opfunu.name_based.a_func import Ackley01
from mealprint import FloatVar

# 1. Define the benchmark function from Opfunu
# We'll use F3 from the CEC 2017 competition with 30 dimensions
ackley_f = Ackley01(ndim=2)

# 2. Define the problem dictionary for MealPrint
# 'obj_func' is the evaluation method from Opfunu
# 'bounds' uses the lb (lower bound) and ub (upper bound) from the Opfunu object
problem_dict = {
    "obj_func": ackley_f.evaluate,
    "bounds": FloatVar(lb=ackley_f.lb, ub=ackley_f.ub),
    "minmax": "min",
}

# %%
import numpy as np
from mealprint.utils.agent import Agent
from mealprint import ClassicOptimizer


class VectorizePSO(ClassicOptimizer):

    def __init__(self, epoch: int = 10000, pop_size: int = 100, c1: float = 2.05, c2: float = 2.05, w: float = 0.4,
                 **kwargs: object) -> None:
        """
        Args:
            epoch: maximum number of iterations, default = 10000
            pop_size: number of population size, default = 100
            c1: [0-2] local coefficient
            c2: [0-2] global coefficient
            w_min: Weight min of bird, default = 0.4
        """

        super().__init__(**kwargs)

        self.epoch = self.validator.check_int("epoch", epoch, [1, 100000])
        self.pop_size = self.validator.check_int("pop_size", pop_size, [5, 10000])
        self.c1 = self.validator.check_float("c1", c1, (0, 5.0))
        self.c2 = self.validator.check_float("c2", c2, (0, 5.0))
        self.w = self.validator.check_float("w", w, (0, 1.0))
        self.set_parameters(["epoch", "pop_size", "c1", "c2", "w"])
        self.sort_flag = False
        self.is_parallelizable = False

        self.v_max = 0
        self.v_min = 0

    def initialize_variables(self):
        self.v_max = 0.5 * (self.problem.ub - self.problem.lb)
        self.v_min = -self.v_max

        self.targets = []

    def generate_empty_agent(self, solution: np.ndarray = None) -> Agent:
        if solution is None:
            solution = self.problem.generate_solution(encoded=True)

        velocity = self.generator.uniform(self.v_min, self.v_max)
        local_pos = solution.copy()

        return Agent(solution=solution, velocity=velocity, local_solution=local_pos)

    def generate_agent(self, solution: np.ndarray = None) -> Agent:
        agent = self.generate_empty_agent(solution)
        agent.target = self.get_target(agent.solution)
        agent.local_target = agent.target.copy()

        return agent

    def amend_solution(self, solution: np.ndarray) -> np.ndarray:
        condition = np.logical_and(self.problem.lb <= solution, solution <= self.problem.ub)
        pos_rand = self.generator.uniform(self.problem.lb, self.problem.ub)

        return np.where(condition, solution, pos_rand)

    def evolve(self, epoch):
        """
        The main operations (equations) of algorithm. Inherit from Optimizer class

        Args:
            epoch (int): The current iteration
        """

        # Update weight after each move count  (weight down)


        for idx in range(0, self.pop_size):
            cognitive = self.c1 * self.generator.random(self.problem.n_dims) * (
                    self.pop[idx].local_solution - self.pop[idx].solution)

            social = self.c2 * self.generator.random(self.problem.n_dims) * (
                    self.g_best.solution - self.pop[idx].solution)

            self.pop[idx].velocity = self.w * self.pop[idx].velocity + cognitive + social

            pos_new = self.pop[idx].solution + self.pop[idx].velocity
            pos_new = self.correct_solution(pos_new)

            target = self.get_target(pos_new)
            self.targets.append(target)

        for idx, target in enumerate(self.targets):
            if self.compare_target(target, self.pop[idx].target, self.problem.minmax):
                self.pop[idx].update(solution=pos_new.copy(), target=target.copy())

            if self.compare_target(target, self.pop[idx].local_target, self.problem.minmax):
                self.pop[idx].update(local_solution=pos_new.copy(), local_target=target.copy())

        self.targets = []

# 3. Initialize and run the PSO algorithm
# epoch: number of iterations, pop_size: number of particles
model = VectorizePSO(epoch=300, pop_size=300)
g_best = model.solve(problem_dict)

# 4. Access the results
print(f"Best solution: {g_best.solution}")
print(f"Best fitness: {g_best.target.fitness}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 103
#      99
#     100 # 3. Initialize and run the PSO algorithm
#     101 # epoch: number of iterations, pop_size: number of particles
#     102 model = OriginalPSOLazy(epoch=300, pop_size=300)
# --> 103 g_best = model.solve(problem_dict)
#     104
#     105 # 4. Access the results
#     106 print(f"Best solution: {g_best.solution}")
#
# File ~/Development/2026/LTSIM/mealprint/mealprint/optimizer/classic.py:246, in ClassicOptimizer.solve(self, problem, termination, starting_solutions, seed, track_optimize)
#     243 time_epoch = time.perf_counter()
#     245 ## Evolve method will be called in child class
# --> 246 self.evolve(epoch)
#     248 # Update global best solution, the population is sorted or not depended on algorithm's strategy
#     249 pop_temp, self.g_best = self.update_global_best_agent(self.pop)
#
# Cell In[29], line 92, in OriginalPSOLazy.evolve(self, epoch)
#      88
#      89             target = self.get_target(pos_new)
#      90             targets.append(target)
#      91
# ---> 92         for idx, target in enumerate(targets):
#      93             if self.compare_target(target, self.pop[idx].target, self.problem.minmax):
#      94                 self.pop[idx].update(solution=pos_new.copy(), target=target.copy())
#      95
#
# File /var/lib/snapd/snap/pycharm-professional/610/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:755, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     753 # if thread has a suspend flag, we suspend with a busy wait
#     754 if info.pydev_state == STATE_SUSPEND:
# --> 755     self.do_wait_suspend(thread, frame, event, arg)
#     756     # No need to reset frame.f_trace to keep the same trace function.
#     757     return self.trace_dispatch
#
# File /var/lib/snapd/snap/pycharm-professional/610/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:412, in PyDBFrame.do_wait_suspend(self, *args, **kwargs)
#     411 def do_wait_suspend(self, *args, **kwargs):
# --> 412     self._args[0].do_wait_suspend(*args, **kwargs)
#
# File /var/lib/snapd/snap/pycharm-professional/610/plugins/python-ce/helpers/pydev/pydevd.py:1195, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1192         from_this_thread.append(frame_id)
#    1194 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1195     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /var/lib/snapd/snap/pycharm-professional/610/plugins/python-ce/helpers/pydev/pydevd.py:1210, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1207             self._call_mpl_hook()
#    1209         self.process_internal_commands()
# -> 1210         time.sleep(0.01)
#    1212 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1214 # process any stepping instructions
#
# KeyboardInterrupt:
