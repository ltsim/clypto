# %%
import numpy as np

# %%
buff = [(np.array([-35., -35., -35., -35., -35.]), np.array([35., 35., 35., 35., 35.]))]
buff
# Out:
# [(array([-35., -35., -35., -35., -35.]), array([35., 35., 35., 35., 35.]))]

# %%
np.vstack(buff)
# Out:
# array([[-35., -35., -35., -35., -35.],
#        [ 35.,  35.,  35.,  35.,  35.]])

# %%
[]
